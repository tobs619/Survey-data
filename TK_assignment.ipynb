# %% [markdown]
# ### This is a sample jupyter notebook

# %% [markdown]
# Jupyter notebook lets you run python from your web browser.<br>
# Here are a few simple things that you can do.

# %% [markdown]
# Print 'Hello World'

# %%
print('Hello World')
# Out:
# Hello World

# %% [markdown]
# Ask user for name and the print it.

# %%
name = input("Please enter your name: ")
print("Hello {}!! Hope you are having fun with jupyter notebooks.".format(name))
# Out:
# Please enter your name: sr
# Hello sr!! Hope you are having fun with jupyter notebooks.

# %% [markdown]
# Import a python module

# %%
import sys

# %% [markdown]
# Print the version of python

# %%
print(sys.version)
# Out:
# 3.7.6 (default, Jan  8 2020, 13:42:34)
# [Clang 4.0.1 (tags/RELEASE_401/final)]

# %% [markdown]
# Print today's date

# %%
import datetime
today = datetime.datetime.today()
print(datetime.datetime.strftime(today,'%d-%B-%Y'))
# Out:
# 29-June-2022

# %%
import os, types
import pandas as pd
from botocore.client import Config
import ibm_boto3

def __iter__(self): return 0

# @hidden_cell
# The following code accesses a file in your IBM Cloud Object Storage. It includes your credentials.
# You might want to remove those credentials before you share the notebook.
client_1e2c40193e164401b933cb1bbb7acfd7 = ibm_boto3.client(service_name='s3',
    ibm_api_key_id='VeIxQoVHTdAdIFnNyI0gbTfxvh3V2ci6QwIoSuGF9WnQ',
    ibm_auth_endpoint="https://iam.cloud.ibm.com/oidc/token",
    config=Config(signature_version='oauth'),
    endpoint_url='https://s3.private.us.cloud-object-storage.appdomain.cloud')

streaming_body_1 = client_1e2c40193e164401b933cb1bbb7acfd7.get_object(Bucket='capstoneproject-donotdelete-pr-fiwivycui0ewwr', Key='Collecting_Jobs_data_Using_API-Questions.ipynb')['Body']

# Your data file was loaded into a botocore.response.StreamingBody object.
# Please read the documentation of ibm_boto3 and pandas to learn more about the possibilities to load the data.
# ibm_boto3 documentation: https://ibm.github.io/ibm-cos-sdk-python/
# pandas documentation: http://pandas.pydata.org/
https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/labs/module%201/Accessing%20Data%20Using%20APIs/Collecting_Jobs_data_Using_API-Questions.ipynb
# @hidden_cell
# The following code contains the credentials for a file in your IBM Cloud Object Storage.
# You might want to remove those credentials before you share your notebook.
credentials_1 = {
    'IAM_SERVICE_ID': 'iam-ServiceId-a96b9618-dab0-48d3-b0f6-18a60a73bc9d',
    'IBM_API_KEY_ID': 'VeIxQoVHTdAdIFnNyI0gbTfxvh3V2ci6QwIoSuGF9WnQ',
    'ENDPOINT': 'https://s3.private.us.cloud-object-storage.appdomain.cloud',
    'IBM_AUTH_ENDPOINT': 'https://iam.cloud.ibm.com/oidc/token',
    'BUCKET': 'capstoneproject-donotdelete-pr-fiwivycui0ewwr',
    'FILE': 'Collecting_Jobs_data_Using_API-Questions.ipynb'
}
# Out:
#   File "/tmp/wsuser/ipykernel_164/665662801.py", line 23
#     https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/labs/module%201/Accessing%20Data%20Using%20APIs/Collecting_Jobs_data_Using_API-Questions.ipynb
#           ^
# SyntaxError: invalid syntax

# %%
import requests # you need this module to make an API call
import pandas as pd

# %%
api_url = "http://api.open-notify.org/astros.json" # this url gives use the astronaut data

# %%
response = requests.get(api_url) # Call the API using the get method and store the
                                # output of the API call in a variable called response.
if response.ok:             # if all is well() no errors, no network timeouts)
    data = response.json()  # store the result in json format in a variable called data
                            # the variable data is of type dictionary.

# %%
print(data)
# Out:
# {'number': 10, 'people': [{'name': 'Oleg Artemyev', 'craft': 'ISS'}, {'name': 'Denis Matveev', 'craft': 'ISS'}, {'name': 'Sergey Korsakov', 'craft': 'ISS'}, {'name': 'Kjell Lindgren', 'craft': 'ISS'}, {'name': 'Bob Hines', 'craft': 'ISS'}, {'name': 'Samantha Cristoforetti', 'craft': 'ISS'}, {'name': 'Jessica Watkins', 'craft': 'ISS'}, {'name': 'Cai Xuzhe', 'craft': 'Tiangong'}, {'name': 'Chen Dong', 'craft': 'Tiangong'}, {'name': 'Liu Yang', 'craft': 'Tiangong'}], 'message': 'success'}

# %%
astronauts = data.get('people')
print("There are {} astronauts on ISS".format(len(astronauts)))
print("And their names are :")
for astronaut in astronauts:
    print(astronaut.get('name'))
# Out:
# There are 10 astronauts on ISS
# And their names are :
# Oleg Artemyev
# Denis Matveev
# Sergey Korsakov
# Kjell Lindgren
# Bob Hines
# Samantha Cristoforetti
# Jessica Watkins
# Cai Xuzhe
# Chen Dong
# Liu Yang

# %%
import pandas as pd
import json

# %%
appi_url="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/labs/module%201/Accessing%20Data%20Using%20APIs/jobs.json?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDA0321ENSkillsNetwork21426264-2022-01-01"
response = requests.get(appi_url) # Call the API using the get method and store the
                                # output of the API call in a variable called response.
if response.ok:             # if all is well() no errors, no network timeouts)
    data = response.json()

# %%
def get_number_of_jobs_T(technology):
    
    #your code goes here
    return technology,number_of_jobs

# %%
print
# Out:
# <function print>

# %%
tk_data=pd.read_json('https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/labs/module%201/Accessing%20Data%20Using%20APIs/jobs.json?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDA0321ENSkillsNetwork21426264-2022-01-01')

# %%
tk_data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/wsuser/ipykernel_164/410642361.py in <module>
# ----> 1 tk_data
#
# NameError: name 'tk_data' is not defined

# %%
def get_number_of_jobs_L(location):
    
    len(location) as number_of_jobs
    return location, number_of_jobs
# Out:
#   File "/tmp/wsuser/ipykernel_164/3538125244.py", line 3
#     len(location) as number_of_jobs
#                   ^
# SyntaxError: invalid syntax

# %%
get_number_of_jobs_L("Los Angeles")
# Out:
# 'Los Angeles'

# %%
data = pd.read_csv('https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/LargeData/m1_survey_data.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/wsuser/ipykernel_164/2943986615.py in <module>
# ----> 1 data = pd.read_csv('https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/LargeData/m1_survey_data.csv')
#
# NameError: name 'pd' is not defined

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/LargeData/m1_survey_data.csv')

# %%
data.head()
# Out:
#    Respondent                      MainBranch Hobbyist  \
# 0           4  I am a developer by profession       No
# 1           9  I am a developer by profession      Yes
# 2          13  I am a developer by profession      Yes
# 3          16  I am a developer by profession      Yes
# 4          17  I am a developer by profession      Yes
#
#                                          OpenSourcer  \
# 0                                              Never
# 1                         Once a month or more often
# 2  Less than once a month but more than once per ...
# 3                                              Never
# 4  Less than once a month but more than once per ...
#
#                                           OpenSource          Employment  \
# 0  The quality of OSS and closed source software ...  Employed full-time
# 1  The quality of OSS and closed source software ...  Employed full-time
# 2  OSS is, on average, of HIGHER quality than pro...  Employed full-time
# 3  The quality of OSS and closed source software ...  Employed full-time
# 4  The quality of OSS and closed source software ...  Employed full-time
#
#           Country Student                                            EdLevel  \
# 0   United States      No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 1     New Zealand      No  Some college/university study without earning ...
# 2   United States      No        Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 3  United Kingdom      No        Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 4       Australia      No           Bachelor’s degree (BA, BS, B.Eng., etc.)
#
#                                       UndergradMajor  ...  \
# 0  Computer science, computer engineering, or sof...  ...
# 1  Computer science, computer engineering, or sof...  ...
# 2  Computer science, computer engineering, or sof...  ...
# 3                                                NaN  ...
# 4  Computer science, computer engineering, or sof...  ...
#
#                               WelcomeChange  \
# 0   Just as welcome now as I felt last year
# 1   Just as welcome now as I felt last year
# 2  Somewhat more welcome now than last year
# 3   Just as welcome now as I felt last year
# 4   Just as welcome now as I felt last year
#
#                                         SONewContent   Age Gender Trans  \
# 0  Tech articles written by other developers;Indu...  22.0    Man    No
# 1                                                NaN  23.0    Man    No
# 2  Tech articles written by other developers;Cour...  28.0    Man    No
# 3  Tech articles written by other developers;Indu...  26.0    Man    No
# 4  Tech articles written by other developers;Indu...  29.0    Man    No
#
#                  Sexuality                              Ethnicity Dependents  \
# 0  Straight / Heterosexual           White or of European descent         No
# 1                 Bisexual           White or of European descent         No
# 2  Straight / Heterosexual           White or of European descent        Yes
# 3  Straight / Heterosexual           White or of European descent         No
# 4  Straight / Heterosexual  Hispanic or Latino/Latina;Multiracial         No
#
#             SurveyLength                  SurveyEase
# 0  Appropriate in length                        Easy
# 1  Appropriate in length  Neither easy nor difficult
# 2  Appropriate in length                        Easy
# 3  Appropriate in length  Neither easy nor difficult
# 4  Appropriate in length                        Easy
#
# [5 rows x 85 columns]

# %%
data.dtypes
# Out:
# Respondent       int64
# MainBranch      object
# Hobbyist        object
# OpenSourcer     object
# OpenSource      object
#                  ...
# Sexuality       object
# Ethnicity       object
# Dependents      object
# SurveyLength    object
# SurveyEase      object
# Length: 85, dtype: object

# %%
len(data)
# Out:
# 11552

# %%
data.shape
# Out:
# (11552, 85)

# %%
ty = data[data.duplicated()]
print (ty)
# Out:
#       Respondent                                         MainBranch Hobbyist  \
# 1168        2339                     I am a developer by profession      Yes
# 1169        2342                     I am a developer by profession      Yes
# 1170        2343                     I am a developer by profession      Yes
# 1171        2344                     I am a developer by profession      Yes
# 1172        2347                     I am a developer by profession      Yes
# ...          ...                                                ...      ...
# 2297        4674  I am not primarily a developer, but I write co...      Yes
# 2298        4675                     I am a developer by profession      Yes
# 2299        4676                     I am a developer by profession      Yes
# 2300        4677                     I am a developer by profession      Yes
# 2301        4679                     I am a developer by profession      Yes
#
#                                             OpenSourcer  \
# 1168                         Once a month or more often
# 1169                                              Never
# 1170  Less than once a month but more than once per ...
# 1171                                              Never
# 1172                                              Never
# ...                                                 ...
# 2297                            Less than once per year
# 2298                                              Never
# 2299                                              Never
# 2300                         Once a month or more often
# 2301  Less than once a month but more than once per ...
#
#                                              OpenSource          Employment  \
# 1168  OSS is, on average, of HIGHER quality than pro...  Employed full-time
# 1169  The quality of OSS and closed source software ...  Employed full-time
# 1170  OSS is, on average, of LOWER quality than prop...  Employed full-time
# 1171  The quality of OSS and closed source software ...  Employed full-time
# 1172  OSS is, on average, of HIGHER quality than pro...  Employed full-time
# ...                                                 ...                 ...
# 2297  The quality of OSS and closed source software ...  Employed full-time
# 2298  OSS is, on average, of HIGHER quality than pro...  Employed full-time
# 2299  OSS is, on average, of HIGHER quality than pro...  Employed full-time
# 2300  OSS is, on average, of HIGHER quality than pro...  Employed full-time
# 2301  The quality of OSS and closed source software ...  Employed full-time
#
#              Country Student  \
# 1168   United States      No
# 1169  United Kingdom      No
# 1170          Canada      No
# 1171   United States      No
# 1172  United Kingdom      No
# ...              ...     ...
# 2297      Bangladesh      No
# 2298   United States      No
# 2299         Finland      No
# 2300  United Kingdom      No
# 2301   United States      No
#
#                                                 EdLevel  \
# 1168  Some college/university study without earning ...
# 1169  Some college/university study without earning ...
# 1170        Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 1171           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 1172        Master’s degree (MA, MS, M.Eng., MBA, etc.)
# ...                                                 ...
# 2297           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 2298           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 2299        Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 2300           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 2301        Master’s degree (MA, MS, M.Eng., MBA, etc.)
#
#                                          UndergradMajor  ...  \
# 1168  Computer science, computer engineering, or sof...  ...
# 1169  Information systems, information technology, o...  ...
# 1170  Computer science, computer engineering, or sof...  ...
# 1171  Computer science, computer engineering, or sof...  ...
# 1172  Computer science, computer engineering, or sof...  ...
# ...                                                 ...  ...
# 2297                                                NaN  ...
# 2298  Information systems, information technology, o...  ...
# 2299  Another engineering discipline (ex. civil, ele...  ...
# 2300  A natural science (ex. biology, chemistry, phy...  ...
# 2301  Computer science, computer engineering, or sof...  ...
#
#                                  WelcomeChange  \
# 1168   Just as welcome now as I felt last year
# 1169  Somewhat more welcome now than last year
# 1170  Somewhat more welcome now than last year
# 1171   Just as welcome now as I felt last year
# 1172   Just as welcome now as I felt last year
# ...                                        ...
# 2297  Somewhat less welcome now than last year
# 2298   Just as welcome now as I felt last year
# 2299  Somewhat less welcome now than last year
# 2300   Just as welcome now as I felt last year
# 2301   Just as welcome now as I felt last year
#
#                                            SONewContent   Age Gender Trans  \
# 1168                                                NaN  24.0    Man    No
# 1169  Tech meetups or events in your area;Courses on...  24.0    Man    No
# 1170  Tech articles written by other developers;Indu...  27.0    Man    No
# 1171  Tech articles written by other developers;Indu...  24.0    Man    No
# 1172                                                NaN   NaN  Woman    No
# ...                                                 ...   ...    ...   ...
# 2297  Tech articles written by other developers;Indu...  31.0    Man    No
# 2298                Tech meetups or events in your area  27.0    Man    No
# 2299                                                NaN  36.0    Man    No
# 2300                                                NaN  40.0    Man    No
# 2301                                                NaN  27.0    Man    No
#
#                                             Sexuality  \
# 1168                          Straight / Heterosexual
# 1169                          Straight / Heterosexual
# 1170                          Straight / Heterosexual
# 1171                          Straight / Heterosexual
# 1172                          Straight / Heterosexual
# ...                                               ...
# 2297  Bisexual;Gay or Lesbian;Straight / Heterosexual
# 2298                          Straight / Heterosexual
# 2299                          Straight / Heterosexual
# 2300                          Straight / Heterosexual
# 2301                                              NaN
#
#                                               Ethnicity Dependents  \
# 1168                       White or of European descent         No
# 1169                       White or of European descent         No
# 1170  Black or of African descent;White or of Europe...         No
# 1171                       White or of European descent         No
# 1172                                           Biracial         No
# ...                                                 ...        ...
# 2297  Black or of African descent;Hispanic or Latino...        Yes
# 2298                       White or of European descent         No
# 2299                       White or of European descent        Yes
# 2300                       White or of European descent        Yes
# 2301                       White or of European descent         No
#
#                SurveyLength                  SurveyEase
# 1168  Appropriate in length                        Easy
# 1169               Too long                        Easy
# 1170  Appropriate in length  Neither easy nor difficult
# 1171  Appropriate in length                        Easy
# 1172               Too long                        Easy
# ...                     ...                         ...
# 2297               Too long  Neither easy nor difficult
# 2298  Appropriate in length                        Easy
# 2299               Too long                        Easy
# 2300  Appropriate in length                        Easy
# 2301  Appropriate in length                        Easy
#
# [154 rows x 85 columns]

# %%
data_removedup = data.drop_duplicates()
print (data_removedup)
# Out:
#        Respondent                      MainBranch Hobbyist  \
# 0               4  I am a developer by profession       No
# 1               9  I am a developer by profession      Yes
# 2              13  I am a developer by profession      Yes
# 3              16  I am a developer by profession      Yes
# 4              17  I am a developer by profession      Yes
# ...           ...                             ...      ...
# 11547       25136  I am a developer by profession      Yes
# 11548       25137  I am a developer by profession      Yes
# 11549       25138  I am a developer by profession      Yes
# 11550       25141  I am a developer by profession      Yes
# 11551       25142  I am a developer by profession      Yes
#
#                                              OpenSourcer  \
# 0                                                  Never
# 1                             Once a month or more often
# 2      Less than once a month but more than once per ...
# 3                                                  Never
# 4      Less than once a month but more than once per ...
# ...                                                  ...
# 11547                                              Never
# 11548                                              Never
# 11549                            Less than once per year
# 11550  Less than once a month but more than once per ...
# 11551  Less than once a month but more than once per ...
#
#                                               OpenSource          Employment  \
# 0      The quality of OSS and closed source software ...  Employed full-time
# 1      The quality of OSS and closed source software ...  Employed full-time
# 2      OSS is, on average, of HIGHER quality than pro...  Employed full-time
# 3      The quality of OSS and closed source software ...  Employed full-time
# 4      The quality of OSS and closed source software ...  Employed full-time
# ...                                                  ...                 ...
# 11547  OSS is, on average, of HIGHER quality than pro...  Employed full-time
# 11548  The quality of OSS and closed source software ...  Employed full-time
# 11549  The quality of OSS and closed source software ...  Employed full-time
# 11550  OSS is, on average, of LOWER quality than prop...  Employed full-time
# 11551  OSS is, on average, of HIGHER quality than pro...  Employed full-time
#
#               Country Student  \
# 0       United States      No
# 1         New Zealand      No
# 2       United States      No
# 3      United Kingdom      No
# 4           Australia      No
# ...               ...     ...
# 11547   United States      No
# 11548          Poland      No
# 11549   United States      No
# 11550     Switzerland      No
# 11551  United Kingdom      No
#
#                                                  EdLevel  \
# 0               Bachelor’s degree (BA, BS, B.Eng., etc.)
# 1      Some college/university study without earning ...
# 2            Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 3            Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 4               Bachelor’s degree (BA, BS, B.Eng., etc.)
# ...                                                  ...
# 11547        Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 11548        Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 11549        Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 11550  Secondary school (e.g. American high school, G...
# 11551          Other doctoral degree (Ph.D, Ed.D., etc.)
#
#                                           UndergradMajor  ...  \
# 0      Computer science, computer engineering, or sof...  ...
# 1      Computer science, computer engineering, or sof...  ...
# 2      Computer science, computer engineering, or sof...  ...
# 3                                                    NaN  ...
# 4      Computer science, computer engineering, or sof...  ...
# ...                                                  ...  ...
# 11547  Computer science, computer engineering, or sof...  ...
# 11548  Computer science, computer engineering, or sof...  ...
# 11549  Computer science, computer engineering, or sof...  ...
# 11550                                                NaN  ...
# 11551  A natural science (ex. biology, chemistry, phy...  ...
#
#                                   WelcomeChange  \
# 0       Just as welcome now as I felt last year
# 1       Just as welcome now as I felt last year
# 2      Somewhat more welcome now than last year
# 3       Just as welcome now as I felt last year
# 4       Just as welcome now as I felt last year
# ...                                         ...
# 11547   Just as welcome now as I felt last year
# 11548     A lot more welcome now than last year
# 11549     A lot more welcome now than last year
# 11550  Somewhat less welcome now than last year
# 11551   Just as welcome now as I felt last year
#
#                                             SONewContent   Age Gender Trans  \
# 0      Tech articles written by other developers;Indu...  22.0    Man    No
# 1                                                    NaN  23.0    Man    No
# 2      Tech articles written by other developers;Cour...  28.0    Man    No
# 3      Tech articles written by other developers;Indu...  26.0    Man    No
# 4      Tech articles written by other developers;Indu...  29.0    Man    No
# ...                                                  ...   ...    ...   ...
# 11547  Tech articles written by other developers;Cour...  36.0    Man    No
# 11548  Tech articles written by other developers;Tech...  25.0    Man    No
# 11549  Tech articles written by other developers;Indu...  34.0    Man    No
# 11550                                                NaN  25.0    Man    No
# 11551  Tech articles written by other developers;Tech...  30.0    Man    No
#
#                      Sexuality                              Ethnicity  \
# 0      Straight / Heterosexual           White or of European descent
# 1                     Bisexual           White or of European descent
# 2      Straight / Heterosexual           White or of European descent
# 3      Straight / Heterosexual           White or of European descent
# 4      Straight / Heterosexual  Hispanic or Latino/Latina;Multiracial
# ...                        ...                                    ...
# 11547  Straight / Heterosexual           White or of European descent
# 11548  Straight / Heterosexual           White or of European descent
# 11549  Straight / Heterosexual           White or of European descent
# 11550  Straight / Heterosexual           White or of European descent
# 11551                 Bisexual           White or of European descent
#
#       Dependents           SurveyLength                  SurveyEase
# 0             No  Appropriate in length                        Easy
# 1             No  Appropriate in length  Neither easy nor difficult
# 2            Yes  Appropriate in length                        Easy
# 3             No  Appropriate in length  Neither easy nor difficult
# 4             No  Appropriate in length                        Easy
# ...          ...                    ...                         ...
# 11547         No  Appropriate in length                   Difficult
# 11548         No  Appropriate in length  Neither easy nor difficult
# 11549        Yes               Too long                        Easy
# 11550         No  Appropriate in length                        Easy
# 11551         No  Appropriate in length                        Easy
#
# [11398 rows x 85 columns]

# %%
data_removedup.isnull().sum()
# Out:
# Respondent                        0
# MainBranch                        0
# Hobbyist                          0
# OpenSourcer                       0
# OpenSource                       81
#                                ...
# Ethnicity                       675
# Dependents                      140
# SurveyLength                     19
# SurveyEase                       14
# NormalizedAnnualCompensation    809
# Length: 86, dtype: int64

# %%
num_vars = data_removedup.columns[data.dtypes != 'object']

print(num_vars)
# Out:
# Index(['Respondent', 'CompTotal', 'ConvertedComp', 'WorkWeekHrs', 'CodeRevHrs',
#        'Age'],
#       dtype='object')

# %%
data_removedup[num_vars].head(10)
# Out:
#    Respondent  CompTotal  ConvertedComp  WorkWeekHrs  CodeRevHrs   Age
# 0           4    61000.0        61000.0         80.0    4.781071  22.0
# 1           9   138000.0        95179.0         32.0   12.000000  23.0
# 2          13    90000.0        90000.0         40.0    5.000000  28.0
# 3          16    29000.0       115464.0         40.0    4.781071  26.0
# 4          17    90000.0        65277.0         45.0    5.000000  29.0
# 5          19     9500.0        31140.0          8.0    3.000000  31.0
# 6          20     3000.0        41244.0        140.0    1.000000  38.0
# 7          22   103000.0       103000.0         40.0    4.781071  47.0
# 8          23    69000.0        69000.0         40.0    8.000000  22.0
# 9          24     8000.0        29019.0         50.0    4.781071  23.0

# %%
data_removedup.describe()
# Out:
#          Respondent     CompTotal  ConvertedComp   WorkWeekHrs   CodeRevHrs  \
# count  11398.000000  1.058900e+04   1.058200e+04  11276.000000  8972.000000
# mean   12490.392437  7.570477e+05   1.315967e+05     42.064606     4.781071
# std     7235.461999  9.705598e+06   2.947865e+05     24.672741     4.567060
# min        4.000000  0.000000e+00   0.000000e+00      3.000000     0.000000
# 25%     6264.250000  2.500000e+04   2.686800e+04     40.000000     2.000000
# 50%    12484.000000  6.500000e+04   5.774500e+04     40.000000     4.000000
# 75%    18784.750000  1.200000e+05   1.000000e+05     43.000000     5.000000
# max    25142.000000  7.000000e+08   2.000000e+06   1012.000000    99.000000
#
#                 Age
# count  11111.000000
# mean      30.778895
# std        7.393686
# min       16.000000
# 25%       25.000000
# 50%       29.000000
# 75%       35.000000
# max       99.000000

# %%
data_removedup['EdLevel'].isnull().sum()
# Out:
# 112

# %%
data_removedup['WorkLoc'].value_counts()
# Out:
# Office                                            6806
# Home                                              3589
# Other place, such as a coworking space or cafe     971
# Name: WorkLoc, dtype: int64

# %%
df2 = data_removedup['WorkLoc'].replace('np.nan', 'Office', regex=True)

# %%
df2.isnull().sum()
# Out:
# 32

# %%
df2 = data_removedup['WorkLoc'].replace ( 'NaN', 'Office')
df2.isnull().sum()
# Out:
# 0

# %%
data_removedup['WorkLoc'].fillna('Office', inplace = True)
# Out:
# /opt/conda/envs/Python-3.9/lib/python3.9/site-packages/pandas/core/generic.py:6392: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return self._update_inplace(result)

# %%
data_removedup['WorkLoc'].isnull().sum()
# Out:
# 0

# %%
data_removedup['Employment'].value_counts()
# Out:
# Employed full-time    10968
# Employed part-time      430
# Name: Employment, dtype: int64

# %%
data_removedup['UndergradMajor'].value_counts()
# Out:
# Computer science, computer engineering, or software engineering          6953
# Information systems, information technology, or system administration     794
# Another engineering discipline (ex. civil, electrical, mechanical)        759
# Web development or web design                                             410
# A natural science (ex. biology, chemistry, physics)                       403
# Mathematics or statistics                                                 372
# A business discipline (ex. accounting, finance, marketing)                244
# A social science (ex. anthropology, psychology, political science)        210
# A humanities discipline (ex. literature, history, philosophy)             207
# Fine arts or performing arts (ex. graphic design, music, studio art)      161
# I never declared a major                                                  124
# A health science (ex. nursing, pharmacy, radiology)                        24
# Name: UndergradMajor, dtype: int64

# %%
data_removedup['ConvertedComp'].isnull().sum()
# Out:
# 816

# %%
data_removedup['ConvertedComp'].value_counts()
# Out:
# 2000000.0    138
# 1000000.0    105
# 100000.0      99
# 150000.0      92
# 120000.0      86
#             ...
# 79183.0        1
# 20475.0        1
# 288732.0       1
# 22056.0        1
# 19880.0        1
# Name: ConvertedComp, Length: 3515, dtype: int64

# %%
data_removedup['CompFreq'].value_counts()
# Out:
# Yearly     6073
# Monthly    4788
# Weekly      331
# Name: CompFreq, dtype: int64

# %%
data_removedup['CompTotal'].value_counts()
# Out:
# 70000.0      241
# 60000.0      239
# 50000.0      223
# 100000.0     218
# 80000.0      194
#             ...
# 163500.0       1
# 2530000.0      1
# 1.0            1
# 162929.0       1
# 74400.0        1
# Name: CompTotal, Length: 1509, dtype: int64

# %%
def f(row):
    if row['CompFreq'] == 'Yearly':
        val = row['CompTotal']
    elif row['CompFreq'] == 'Monthly':
        val = row['CompTotal'] * 12
    else:
        val = row['CompTotal'] * 52
    return val
data_removedup['NormalizedAnnualCompensation'] = data_removedup.apply(f, axis=1)
# Out:
# /tmp/wsuser/ipykernel_164/3214726448.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_removedup['NormalizedAnnualCompensation'] = data_removedup.apply(f, axis=1)

# %%
data_removedup[['NormalizedAnnualCompensation','CompTotal', 'CompFreq']]
# Out:
#        NormalizedAnnualCompensation  CompTotal CompFreq
# 0                           61000.0    61000.0   Yearly
# 1                          138000.0   138000.0   Yearly
# 2                           90000.0    90000.0   Yearly
# 3                          348000.0    29000.0  Monthly
# 4                           90000.0    90000.0   Yearly
# ...                             ...        ...      ...
# 11547                      130000.0   130000.0   Yearly
# 11548                       74400.0    74400.0   Yearly
# 11549                      105000.0   105000.0   Yearly
# 11550                       80000.0    80000.0   Yearly
# 11551                    39366480.4   757047.7      NaN
#
# [11398 rows x 3 columns]

# %%
import matplotlib.pyplot as plt
from scipy.stats import norm

# %%
dt = data_removedup[['ConvertedComp']]
plt.plot(dt, norm.pdf(dt, 1.315967e+05	, 2.947865e+05), color ='red')

# %%
data_removedup['Gender'].value_counts()
# Out:
# Man                                                            10480
# Woman                                                            731
# Non-binary, genderqueer, or gender non-conforming                 63
# Man;Non-binary, genderqueer, or gender non-conforming             26
# Woman;Non-binary, genderqueer, or gender non-conforming           14
# Woman;Man                                                          9
# Woman;Man;Non-binary, genderqueer, or gender non-conforming        2
# Name: Gender, dtype: int64

# %%
data_removedup.hist(column='ConvertedComp',
        grid = False,
        figsize=(14, 6),
        legend=True,
        orientation='vertical',
        color='red');

# %%
import pandas as pd
import seaborn as sns
sns.set(style="darkgrid", font_scale=1.2)

# %%
sns.displot(
  data=data_removedup,
  x="ConvertedComp",
  kind="hist",
    bins = 20
)

# %%
def g(row):
    if row['Gender'] == 'Woman':
        vall = row['ConvertedComp']
    else:
        vall = 0
    return vall
data_ = data_removedup.apply(g, axis=1)

# %%
data_.isnull().sum()
# Out:
# 52

# %%
data_removedup['Woman'].value_counts()
# Out:
# 0.0         10670
# 75000.0        11
# 90000.0        10
# 120000.0        8
# 110000.0        8
#             ...
# 659568.0        1
# 419724.0        1
# 67800.0         1
# 70354.0         1
# 38760.0         1
# Name: Woman, Length: 473, dtype: int64

# %%
data_removedup['Age'].isnull().sum()
# Out:
# 0

# %%
data_removedup['Respondent'].isnull().sum()
# Out:
# 0

# %%
data_removedup['Age'].fillna(30, inplace = True)
# Out:
# /opt/conda/envs/Python-3.9/lib/python3.9/site-packages/pandas/core/generic.py:6392: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return self._update_inplace(result)

# %%
data_removedup['CompTotal'].mean()
# Out:
# 757047.7255642648

# %%
data_removedup['ConvertedComp'].mean()
# Out:
# 131596.7316197316

# %%
data_removedup['ConvertedComp'].fillna(131596.7, inplace = True)

# %%
data_removedup['CompTotal'].fillna(757047.7, inplace = True)

# %%
data_removedup['Age'].mean()
# Out:
# 30.778894788947888

# %%
data_removedup['WorkWeekHrs'].isnull().sum()
# Out:
# 0

# %%
data_removedup['WorkWeekHrs'].mean()
# Out:
# 42.064606243348706

# %%
data_removedup['WorkWeekHrs'].fillna(data_removedup['WorkWeekHrs'].mean(), inplace = True)

# %%
data_removedup['CodeRevHrs'].fillna(data_removedup['CodeRevHrs'].mean(), inplace = True)

# %%
sns.displot(
  data=data_removedup,
  x="Age",
  kind="hist",
    bins = 20
)

# %%
plt.figure(figsize=(16,7))
data_removedup['ConvertedComp'].plot(kind='box')
plt.semilogy();

# %%
data_removedup['ConvertedComp'].median()
# Out:
# 63016.0

# %%
lower_limit = data_removedup['ConvertedComp'].quantile(0.25)
upper_limit  = data_removedup['ConvertedComp'].quantile(0.75)

# %%
upper_limit = data_removedup['ConvertedComp'].mean() + 3*data_removedup['ConvertedComp'].std()
lower_limit = data_removedup['ConvertedComp'].mean() - 3*data_removedup['ConvertedComp'].std()

# %%
print("Highest allowed",data_removedup['ConvertedComp'].mean() + 3*data_removedup['ConvertedComp'].std())
print("Lowest allowed",data_removedup['ConvertedComp'].mean() - 3*data_removedup['ConvertedComp'].std())
# Out:
# Highest allowed 173429.90802493144
# Lowest allowed -35771.53725813025

# %%
data_removedup[(data_removedup['ConvertedComp'] > 173429.90802493144) | (data_removedup['ConvertedComp'] < 35771.53725813025)]
# Out:
#        Respondent                      MainBranch Hobbyist  \
# 5              19  I am a developer by profession      Yes
# 9              24  I am a developer by profession      Yes
# 10             25  I am a developer by profession       No
# 16             43  I am a developer by profession      Yes
# 19             50  I am a developer by profession      Yes
# ...           ...                             ...      ...
# 11542       25124  I am a developer by profession      Yes
# 11543       25125  I am a developer by profession       No
# 11544       25128  I am a developer by profession      Yes
# 11546       25134  I am a developer by profession      Yes
# 11548       25137  I am a developer by profession      Yes
#
#                                              OpenSourcer  \
# 5                                                  Never
# 9                                                  Never
# 10                                                 Never
# 16                               Less than once per year
# 19                            Once a month or more often
# ...                                                  ...
# 11542                         Once a month or more often
# 11543                                              Never
# 11544  Less than once a month but more than once per ...
# 11546  Less than once a month but more than once per ...
# 11548                                              Never
#
#                                               OpenSource          Employment  \
# 5      The quality of OSS and closed source software ...  Employed full-time
# 9      OSS is, on average, of HIGHER quality than pro...  Employed full-time
# 10     OSS is, on average, of HIGHER quality than pro...  Employed full-time
# 16     OSS is, on average, of HIGHER quality than pro...  Employed full-time
# 19     OSS is, on average, of LOWER quality than prop...  Employed full-time
# ...                                                  ...                 ...
# 11542  OSS is, on average, of HIGHER quality than pro...  Employed full-time
# 11543  OSS is, on average, of HIGHER quality than pro...  Employed full-time
# 11544  OSS is, on average, of HIGHER quality than pro...  Employed full-time
# 11546  OSS is, on average, of HIGHER quality than pro...  Employed full-time
# 11548  The quality of OSS and closed source software ...  Employed full-time
#
#             Country         Student  \
# 5            Brazil              No
# 9            Israel              No
# 10     South Africa              No
# 16            Spain              No
# 19            India              No
# ...             ...             ...
# 11542         India  Yes, full-time
# 11543         Italy              No
# 11544         India  Yes, part-time
# 11546       Ecuador              No
# 11548        Poland              No
#
#                                                  EdLevel  \
# 5      Some college/university study without earning ...
# 9                              Primary/elementary school
# 10                                      Associate degree
# 16              Bachelor’s degree (BA, BS, B.Eng., etc.)
# 19              Bachelor’s degree (BA, BS, B.Eng., etc.)
# ...                                                  ...
# 11542  Some college/university study without earning ...
# 11543           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 11544           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 11546           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 11548        Master’s degree (MA, MS, M.Eng., MBA, etc.)
#
#                                           UndergradMajor  ...  \
# 5      Computer science, computer engineering, or sof...  ...
# 9                                                    NaN  ...
# 10     Computer science, computer engineering, or sof...  ...
# 16     Computer science, computer engineering, or sof...  ...
# 19     Another engineering discipline (ex. civil, ele...  ...
# ...                                                  ...  ...
# 11542  Computer science, computer engineering, or sof...  ...
# 11543  Computer science, computer engineering, or sof...  ...
# 11544  Another engineering discipline (ex. civil, ele...  ...
# 11546  Computer science, computer engineering, or sof...  ...
# 11548  Computer science, computer engineering, or sof...  ...
#
#                                   WelcomeChange  \
# 5       Just as welcome now as I felt last year
# 9       Just as welcome now as I felt last year
# 10      Just as welcome now as I felt last year
# 16      Just as welcome now as I felt last year
# 19      Just as welcome now as I felt last year
# ...                                         ...
# 11542   Just as welcome now as I felt last year
# 11543   Just as welcome now as I felt last year
# 11544   Just as welcome now as I felt last year
# 11546  Somewhat less welcome now than last year
# 11548     A lot more welcome now than last year
#
#                                             SONewContent   Age Gender Trans  \
# 5      Tech articles written by other developers;Indu...  31.0    Man    No
# 9      Tech articles written by other developers;Indu...  23.0    Man    No
# 10                   Tech meetups or events in your area  22.0    Man    No
# 16     Tech articles written by other developers;Tech...  27.0    Man    No
# 19     Tech articles written by other developers;Tech...  23.0    Man    No
# ...                                                  ...   ...    ...   ...
# 11542  Industry news about technologies you're intere...  26.0    Man    No
# 11543          Tech articles written by other developers  26.0    Man    No
# 11544  Tech articles written by other developers;Tech...  26.0    Man    No
# 11546          Tech articles written by other developers  32.0    Man    No
# 11548  Tech articles written by other developers;Tech...  25.0    Man    No
#
#                      Sexuality                     Ethnicity Dependents  \
# 5      Straight / Heterosexual     Hispanic or Latino/Latina        Yes
# 9      Straight / Heterosexual                Middle Eastern         No
# 10     Straight / Heterosexual  White or of European descent         No
# 16     Straight / Heterosexual     Hispanic or Latino/Latina         No
# 19                         NaN                   South Asian         No
# ...                        ...                           ...        ...
# 11542  Straight / Heterosexual                   South Asian        Yes
# 11543  Straight / Heterosexual  White or of European descent         No
# 11544  Straight / Heterosexual                   South Asian        Yes
# 11546  Straight / Heterosexual     Hispanic or Latino/Latina         No
# 11548  Straight / Heterosexual  White or of European descent         No
#
#                 SurveyLength                  SurveyEase
# 5                   Too long                        Easy
# 9      Appropriate in length                        Easy
# 10                 Too short  Neither easy nor difficult
# 16                  Too long                        Easy
# 19                  Too long                        Easy
# ...                      ...                         ...
# 11542  Appropriate in length                   Difficult
# 11543  Appropriate in length                        Easy
# 11544  Appropriate in length                        Easy
# 11546  Appropriate in length                        Easy
# 11548  Appropriate in length  Neither easy nor difficult
#
# [3426 rows x 85 columns]

# %%
data_removedup['ConvertedComp'].describe()
# Out:
# count     11398.000000
# mean      68829.935515
# std       34866.050939
# min       29019.000000
# 25%       29021.250000
# 50%       63016.000000
# 75%      115464.000000
# max      115464.000000
# Name: ConvertedComp, dtype: float64

# %%
pd.set_option("display.max_columns", None)
# display the dataframe head
data_removedup.head()
# Out:
#    Respondent                      MainBranch Hobbyist  \
# 0           4  I am a developer by profession       No
# 1           9  I am a developer by profession      Yes
# 2          13  I am a developer by profession      Yes
# 3          16  I am a developer by profession      Yes
# 4          17  I am a developer by profession      Yes
#
#                                          OpenSourcer  \
# 0                                              Never
# 1                         Once a month or more often
# 2  Less than once a month but more than once per ...
# 3                                              Never
# 4  Less than once a month but more than once per ...
#
#                                           OpenSource          Employment  \
# 0  The quality of OSS and closed source software ...  Employed full-time
# 1  The quality of OSS and closed source software ...  Employed full-time
# 2  OSS is, on average, of HIGHER quality than pro...  Employed full-time
# 3  The quality of OSS and closed source software ...  Employed full-time
# 4  The quality of OSS and closed source software ...  Employed full-time
#
#           Country Student                                            EdLevel  \
# 0   United States      No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 1     New Zealand      No  Some college/university study without earning ...
# 2   United States      No        Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 3  United Kingdom      No        Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 4       Australia      No           Bachelor’s degree (BA, BS, B.Eng., etc.)
#
#                                       UndergradMajor  \
# 0  Computer science, computer engineering, or sof...
# 1  Computer science, computer engineering, or sof...
# 2  Computer science, computer engineering, or sof...
# 3                                                NaN
# 4  Computer science, computer engineering, or sof...
#
#                                             EduOther               OrgSize  \
# 0  Taken an online course in programming or softw...  100 to 499 employees
# 1  Taken an online course in programming or softw...    10 to 19 employees
# 2  Taken an online course in programming or softw...    10 to 19 employees
# 3  Taken an online course in programming or softw...  100 to 499 employees
# 4  Taken an online course in programming or softw...    20 to 99 employees
#
#                                              DevType YearsCode Age1stCode  \
# 0                              Developer, full-stack         3         16
# 1  Database administrator;Developer, back-end;Dev...        12         11
# 2  Data or business analyst;Database administrato...        17         11
# 3                              Developer, full-stack        10         17
# 4  Developer, back-end;Developer, front-end;Devel...         5         18
#
#        YearsCodePro           CareerSat                              JobSat  \
# 0  Less than 1 year      Very satisfied                  Slightly satisfied
# 1                 4  Slightly satisfied                  Slightly satisfied
# 2                 8      Very satisfied                      Very satisfied
# 3                 3      Very satisfied                  Slightly satisfied
# 4                 2  Slightly satisfied  Neither satisfied nor dissatisfied
#
#              MgrIdiot MgrMoney   MgrWant  \
# 0      Very confident       No  Not sure
# 1  Somewhat confident       No  Not sure
# 2                 NaN      NaN       NaN
# 3  Somewhat confident       No        No
# 4  Somewhat confident       No        No
#
#                                              JobSeek          LastHireDate  \
# 0       I am not interested in new job opportunities  Less than a year ago
# 1  I’m not actively looking, but I am open to new...  Less than a year ago
# 2       I am not interested in new job opportunities         3-4 years ago
# 3  I’m not actively looking, but I am open to new...         3-4 years ago
# 4                    I am actively looking for a job  Less than a year ago
#
#                                              LastInt FizzBuzz  \
# 0  Write code by hand (e.g., on a whiteboard);Int...       No
# 1  Write any code;Interview with people in peer r...      Yes
# 2  Complete a take-home project;Interview with pe...      Yes
# 3  Interview with people in senior / management r...      Yes
# 4  Complete a take-home project;Interview with pe...       No
#
#                                           JobFactors  \
# 0  Languages, frameworks, and other technologies ...
# 1  Financial performance or funding status of the...
# 2  Languages, frameworks, and other technologies ...
# 3  Languages, frameworks, and other technologies ...
# 4  Languages, frameworks, and other technologies ...
#
#                                         ResumeUpdate CurrencySymbol  \
# 0                   I was preparing for a job search            USD
# 1                   I was preparing for a job search            NZD
# 2                   I was preparing for a job search            USD
# 3  I heard about a job opportunity (from a recrui...            GBP
# 4                   I was preparing for a job search            AUD
#
#            CurrencyDesc  CompTotal CompFreq  ConvertedComp  WorkWeekHrs  \
# 0  United States dollar    61000.0   Yearly        61000.0         80.0
# 1    New Zealand dollar   138000.0   Yearly        95179.0         32.0
# 2  United States dollar    90000.0   Yearly        90000.0         40.0
# 3        Pound sterling    29000.0  Monthly       115464.0         40.0
# 4     Australian dollar    90000.0   Yearly        65277.0         45.0
#
#                                             WorkPlan  \
# 0  There's no schedule or spec; I work on what se...
# 1  There is a schedule and/or spec (made by me or...
# 2  There is a schedule and/or spec (made by me or...
# 3  There is a schedule and/or spec (made by me or...
# 4  There's no schedule or spec; I work on what se...
#
#                                        WorkChallenge  \
# 0                                                NaN
# 1  Being tasked with non-development work;Inadequ...
# 2  Meetings;Non-work commitments (parenting, scho...
# 3  Being tasked with non-development work;Distrac...
# 4  Distracting work environment;Meetings;Time spe...
#
#                                           WorkRemote  \
# 0                   Less than once per month / Never
# 1                   Less than once per month / Never
# 2  All or almost all the time (I'm full-time remote)
# 3                              A few days each month
# 4                              A few days each month
#
#                                           WorkLoc                  ImpSyn  \
# 0                                            Home  A little below average
# 1                                          Office  A little above average
# 2                                            Home  A little above average
# 3                                            Home                 Average
# 4  Other place, such as a coworking space or cafe  A little above average
#
#                                    CodeRev  CodeRevHrs  \
# 0                                       No    4.781071
# 1  Yes, because I see value in code review   12.000000
# 2  Yes, because I see value in code review    5.000000
# 3                                       No    4.781071
# 4  Yes, because I see value in code review    5.000000
#
#                                            UnitTests  \
# 0                          No, but I think we should
# 1  Yes, it's not part of our process but the deve...
# 2                          No, but I think we should
# 3                          No, but I think we should
# 4                      Yes, it's part of our process
#
#                                          PurchaseHow  \
# 0  Developers typically have the most influence o...
# 1                                           Not sure
# 2  Developers and management have nearly equal in...
# 3  Developers and management have nearly equal in...
# 4  Developers typically have the most influence o...
#
#                        PurchaseWhat  \
# 0     I have little or no influence
# 1             I have some influence
# 2  I have a great deal of influence
# 3             I have some influence
# 4     I have little or no influence
#
#                                   LanguageWorkedWith  \
# 0                                C;C++;C#;Python;SQL
# 1  Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;P...
# 2  Bash/Shell/PowerShell;HTML/CSS;JavaScript;PHP;...
# 3  Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;T...
# 4  Bash/Shell/PowerShell;HTML/CSS;JavaScript;Type...
#
#                               LanguageDesireNextYear  \
# 0                                C;C#;JavaScript;SQL
# 1  Bash/Shell/PowerShell;C;HTML/CSS;JavaScript;Ru...
# 2  Bash/Shell/PowerShell;HTML/CSS;JavaScript;Rust...
# 3  C#;HTML/CSS;JavaScript;TypeScript;WebAssembly;...
# 4  Bash/Shell/PowerShell;HTML/CSS;Java;JavaScript...
#
#                    DatabaseWorkedWith  \
# 0                        MySQL;SQLite
# 1          DynamoDB;PostgreSQL;SQLite
# 2   Couchbase;DynamoDB;Firebase;MySQL
# 3  MongoDB;Microsoft SQL Server;MySQL
# 4                  MongoDB;PostgreSQL
#
#                               DatabaseDesireNextYear  \
# 0                                       MySQL;SQLite
# 1                            PostgreSQL;Redis;SQLite
# 2                               Firebase;MySQL;Redis
# 3  Elasticsearch;MongoDB;Microsoft SQL Server;SQLite
# 4          Elasticsearch;Firebase;MongoDB;PostgreSQL
#
#                                   PlatformWorkedWith  \
# 0                                      Linux;Windows
# 1                AWS;Docker;Heroku;Linux;MacOS;Slack
# 2  Android;AWS;Docker;IBM Cloud or Watson;iOS;Lin...
# 3                                                NaN
# 4       Arduino;Docker;Heroku;Raspberry Pi;WordPress
#
#                               PlatformDesireNextYear  \
# 0                                      Linux;Windows
# 1      AWS;Docker;Heroku;Linux;MacOS;Slack;Other(s):
# 2  Android;AWS;Docker;IBM Cloud or Watson;Linux;S...
# 3          AWS;Google Cloud Platform;Microsoft Azure
# 4                                             Docker
#
#                                  WebFrameWorkedWith  \
# 0                                               NaN
# 1                   Express;Ruby on Rails;Other(s):
# 2  Angular/Angular.js;ASP.NET;Express;jQuery;Vue.js
# 3                 Angular/Angular.js;ASP.NET;jQuery
# 4                 Angular/Angular.js;Express;Spring
#
#                               WebFrameDesireNextYear      MiscTechWorkedWith  \
# 0                                                NaN                    .NET
# 1                    Express;Ruby on Rails;Other(s):        Node.js;Unity 3D
# 2                                     Express;Vue.js         Node.js;Xamarin
# 3                Angular/Angular.js;ASP.NET;React.js  .NET;.NET Core;Node.js
# 4  Angular/Angular.js;Express;React.js;Spring;Vue.js                 Node.js
#
#            MiscTechDesireNextYear  \
# 0                            .NET
# 1                         Node.js
# 2              Node.js;TensorFlow
# 3  .NET Core;Node.js;React Native
# 4            Node.js;React Native
#
#                                      DevEnviron        OpSys  \
# 0  Eclipse;Vim;Visual Studio;Visual Studio Code      Windows
# 1                                           Vim        MacOS
# 2    Vim;Visual Studio;Visual Studio Code;Xcode      Windows
# 3              Visual Studio;Visual Studio Code      Windows
# 4                   IntelliJ;Visual Studio Code  Linux-based
#
#                                           Containers BlockchainOrg  \
# 0                            I do not use containers    Not at all
# 1                     Development;Testing;Production    Not at all
# 2                     Development;Testing;Production    Not at all
# 3                            I do not use containers    Not at all
# 4  Development;Testing;Production;Outside of work...    Not at all
#
#                                         BlockchainIs BetterLife  \
# 0  Useful for decentralized currency (i.e., Bitcoin)        Yes
# 1                  An irresponsible use of resources         No
# 2  Useful for decentralized currency (i.e., Bitcoin)        Yes
# 3                                      A passing fad         No
# 4                                      A passing fad        Yes
#
#                                    ITperson  OffOn SocialMedia  \
# 0                                      SIGH    Yes      Reddit
# 1                                      SIGH    Yes     Twitter
# 2                                       Yes    Yes     Twitter
# 3                                      SIGH     No     YouTube
# 4  Fortunately, someone else has that title  What?     YouTube
#
#                Extraversion ScreenName SOVisit1st             SOVisitFreq  \
# 0  In real life (in person)   Username       2014   Daily or almost daily
# 1  In real life (in person)   Username       2013   Daily or almost daily
# 2  In real life (in person)   Username       2011  Multiple times per day
# 3                    Online   Username       2010  Multiple times per day
# 4  In real life (in person)        NaN       2014   Daily or almost daily
#
#                                            SOVisitTo  \
# 0  Find answers to specific questions;Pass the ti...
# 1  Find answers to specific questions;Contribute ...
# 2                 Find answers to specific questions
# 3  Find answers to specific questions;Learn how t...
# 4  Find answers to specific questions;Learn how t...
#
#                   SOFindAnswer                         SOTimeSaved  \
# 0           1-2 times per week      Stack Overflow was much faster
# 1           3-5 times per week            They were about the same
# 2  More than 10 times per week      Stack Overflow was much faster
# 3      Less than once per week      Stack Overflow was much faster
# 4          6-10 times per week  Stack Overflow was slightly faster
#
#    SOHowMuchTime SOAccount                           SOPartFreq  \
# 0  31-60 minutes       Yes  Less than once per month or monthly
# 1            NaN       Yes  Less than once per month or monthly
# 2  11-30 minutes       Yes  Less than once per month or monthly
# 3  11-30 minutes       Yes  Less than once per month or monthly
# 4   0-10 minutes       Yes                 A few times per week
#
#                                               SOJobs  \
# 0                                                Yes
# 1  No, I knew that Stack Overflow had a job board...
# 2                                                Yes
# 3                                                Yes
# 4  No, I didn't know that Stack Overflow had a jo...
#
#                                             EntTeams          SOComm  \
# 0                No, and I don't know what those are  No, not really
# 1                No, and I don't know what those are   Yes, somewhat
# 2  No, I've heard of them, but I am not part of a...         Neutral
# 3  No, I've heard of them, but I am not part of a...   Yes, somewhat
# 4  No, I've heard of them, but I am not part of a...   Yes, somewhat
#
#                               WelcomeChange  \
# 0   Just as welcome now as I felt last year
# 1   Just as welcome now as I felt last year
# 2  Somewhat more welcome now than last year
# 3   Just as welcome now as I felt last year
# 4   Just as welcome now as I felt last year
#
#                                         SONewContent   Age Gender Trans  \
# 0  Tech articles written by other developers;Indu...  22.0    Man    No
# 1                                                NaN  23.0    Man    No
# 2  Tech articles written by other developers;Cour...  28.0    Man    No
# 3  Tech articles written by other developers;Indu...  26.0    Man    No
# 4  Tech articles written by other developers;Indu...  29.0    Man    No
#
#                  Sexuality                              Ethnicity Dependents  \
# 0  Straight / Heterosexual           White or of European descent         No
# 1                 Bisexual           White or of European descent         No
# 2  Straight / Heterosexual           White or of European descent        Yes
# 3  Straight / Heterosexual           White or of European descent         No
# 4  Straight / Heterosexual  Hispanic or Latino/Latina;Multiracial         No
#
#             SurveyLength                  SurveyEase  \
# 0  Appropriate in length                        Easy
# 1  Appropriate in length  Neither easy nor difficult
# 2  Appropriate in length                        Easy
# 3  Appropriate in length  Neither easy nor difficult
# 4  Appropriate in length                        Easy
#
#    NormalizedAnnualCompensation
# 0                       61000.0
# 1                      138000.0
# 2                       90000.0
# 3                      348000.0
# 4                       90000.0

# %%
data_removedup['DatabaseWorkedWith'].value_counts()
# Out:
# Microsoft SQL Server                                                                         845
# MySQL                                                                                        474
# PostgreSQL                                                                                   351
# Microsoft SQL Server;MySQL                                                                   281
# SQLite                                                                                       192
#                                                                                             ...
# DynamoDB;MongoDB;MySQL;Oracle;PostgreSQL;SQLite                                                1
# DynamoDB;Firebase;MySQL;Redis;SQLite                                                           1
# Couchbase;SQLite;Other(s):                                                                     1
# Couchbase;Elasticsearch;MariaDB;MongoDB;Microsoft SQL Server;MySQL;Redis;SQLite;Other(s):      1
# Cassandra;Elasticsearch;MariaDB;MongoDB;PostgreSQL;Redis                                       1
# Name: DatabaseWorkedWith, Length: 1560, dtype: int64

# %%
data_removedup['ConvertedComp'] = np.where(
    data_removedup['ConvertedComp']>upper_limit,
    upper_limit,
    np.where(
        data_removedup['ConvertedComp']<lower_limit,
        lower_limit,
        data_removedup['ConvertedComp']
    )
)
# Out:
# /tmp/wsuser/ipykernel_164/3682270762.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_removedup['ConvertedComp'] = np.where(

# %%
plt.figure(figsize=(16,7))
data_removedup['Age'].plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
print(np.where(data_removedup['Age']>60))
# Out:
# (array([  614,   747,   756,  1185,  1595,  1658,  1927,  2322,  2614,
#         3190,  3323,  3376,  3531,  3779,  4614,  5804,  6168,  6227,
#         6421,  6545,  7697,  7825,  8080,  8998,  9198, 10054, 10333,
#        10334, 10370, 10452, 11063]),)

# %%
fig, ax = plt.subplots(figsize = (18,10))
ax.scatter(data_removedup['Age'], data_removedup['WorkWeekHrs'])
 

plt.show()

# %%
# scatter plot with scatter() function
# transparency with "alpha"
# bubble size with "s"
plt.figure(figsize=(16,7))
plt.scatter('WorkWeekHrs', 'CodeRevHrs', 
             s='Age',
             alpha=1, 
             data=data_removedup)
plt.xlabel("WorkWeekHrs", size=16)
plt.ylabel("CodeRevHrs", size=16)
plt.title("Bubble Plot with Matplotlib", size=18)
# Out:
# Text(0.5, 1.0, 'Bubble Plot with Matplotlib')

# %%
from scipy.stats.stats import pearsonr

# %%
Index(['Respondent', 'CompTotal', 'ConvertedComp', 'WorkWeekHrs', 'CodeRevHrs',
       'Age']

# %%
a = data_removedup['Age']
b = data_removedup['Respondent']
c = data_removedup['CompTotal']
d = data_removedup['ConvertedComp']
e = data_removedup['WorkWeekHrs']
f = data_removedup['CodeRevHrs']

pearsonr(a, b)
# Out:
# (0.00411941666783183, 0.6601193514941415)

# %%
pearsonr(a, c)
# Out:
# (0.006823924332596398, 0.4663317976667701)

# %%
pearsonr(a, d)
# Out:
# (0.3109204611690082, 6.156420258046433e-254)

# %%
pearsonr(a, e)
# Out:
# (0.03650906372215979, 9.673785568560238e-05)

# %%
pearsonr(a, f)
# Out:
# (-0.017622963631404767, 0.05991857361895499)

# %%
# !wget https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/LargeData/m4_survey_data.sqlite
# Out:
# --2022-07-06 13:43:12--  https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/LargeData/m4_survey_data.sqlite
# Resolving cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud (cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud)... 198.23.119.245
# Connecting to cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud (cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud)|198.23.119.245|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 36679680 (35M) [application/octet-stream]
# Saving to: ‘m4_survey_data.sqlite’
#
# m4_survey_data.sqli 100%[===================>]  34.98M  27.5MB/s    in 1.3s
#
# 2022-07-06 13:43:13 (27.5 MB/s) - ‘m4_survey_data.sqlite’ saved [36679680/36679680]

# %%
import sqlite3
conn = sqlite3.connect("m4_survey_data.sqlite")

# %%
QUERY = "SELECT COUNT(*) FROM master"

# %%
df = pd.read_sql_query(QUERY,conn)
df.head()
# Out:
#    COUNT(*)
# 0     11398

# %%
QUERY = """
SELECT name as Table_Name FROM
sqlite_master WHERE
type = 'table'
"""
# the read_sql_query runs the sql query and returns the data as a dataframe
pd.read_sql_query(QUERY,conn)
# Out:
#                 Table_Name
# 0                 EduOther
# 1                  DevType
# 2                  LastInt
# 3               JobFactors
# 4                 WorkPlan
# 5            WorkChallenge
# 6       LanguageWorkedWith
# 7   LanguageDesireNextYear
# 8       DatabaseWorkedWith
# 9   DatabaseDesireNextYear
# 10      PlatformWorkedWith
# 11  PlatformDesireNextYear
# 12      WebFrameWorkedWith
# 13  WebFrameDesireNextYear
# 14      MiscTechWorkedWith
# 15  MiscTechDesireNextYear
# 16              DevEnviron
# 17              Containers
# 18               SOVisitTo
# 19            SONewContent
# 20                  Gender
# 21               Sexuality
# 22               Ethnicity
# 23                  master

# %%
QUERY = """
SELECT ConvertedComp FROM master

"""
by = pd.read_sql_query(QUERY,conn)

# %%
by
# Out:
#        ConvertedComp
# 0            61000.0
# 1            95179.0
# 2            90000.0
# 3           455352.0
# 4            65277.0
# ...              ...
# 11393       130000.0
# 11394        19880.0
# 11395       105000.0
# 11396        80371.0
# 11397            NaN
#
# [11398 rows x 1 columns]

# %%
by.plot(kind = 'hist',
        grid = True,
        figsize=(14, 6),
        legend=True,
        orientation='vertical',
        color='red');

# %%
QUERY = """
SELECT LanguageDesireNextYear, COUNT(Respondent) as count
FROM LanguageDesireNextYear
group by LanguageDesireNextYear

order by count desc limit 10
"""
fg = pd.read_sql_query(QUERY,conn)
fg
# Out:
#   LanguageDesireNextYear  count
# 0             JavaScript   6630
# 1               HTML/CSS   5328
# 2                 Python   5239
# 3                    SQL   5012
# 4             TypeScript   4088
# 5                     C#   3591
# 6  Bash/Shell/PowerShell   3097
# 7                   Java   2953
# 8                     Go   2759
# 9                 Kotlin   1890

# %%
QUERY = """
SELECT DatabaseDesireNextYear, COUNT(Respondent) as count
FROM DatabaseDesireNextYear
group by DatabaseDesireNextYear
order by count desc limit 10
"""
bk = pd.read_sql_query(QUERY,conn)

# %%
bk
# Out:
#   DatabaseDesireNextYear  count
# 0             PostgreSQL   4328
# 1                MongoDB   3649
# 2                  Redis   3331
# 3                  MySQL   3281
# 4          Elasticsearch   2856
# 5   Microsoft SQL Server   2706
# 6                 SQLite   2437
# 7               Firebase   1650
# 8                MariaDB   1385
# 9               DynamoDB   1044

# %%
my_labels = ('PostgreSQL','MongoDB','Redis','MySQL','Elasticsearch')
bk.plot(kind = 'pie', y = 'count', labels=my_labels,autopct='%1.1f%%',figsize=(20, 10))


plt.title('Next Year')

plt.show()

# %%
QUERY = 'SELECT WorkWeekHrs, CodeRevHrs from master GROUP BY Age HAVING SUM(SIGN(1-SIGN(WorkWeekHrs-CodeRevHrs)))/COUNT(*) > .5'

bb = pd.read_sql_query(QUERY,conn)
bb
# Out:
# Empty DataFrame
# Columns: [WorkWeekHrs, CodeRevHrs]
# Index: []

# %%
QUERY = """
SELECT WorkWeekHrs, CodeRevHrs, Age
FROM master where Age between 30 and 35 group by Age 
"""
tk = pd.read_sql_query(QUERY,conn)
tk
# Out:
#    WorkWeekHrs  CodeRevHrs   Age
# 0         40.0         5.0  30.0
# 1          8.0         3.0  31.0
# 2         40.0         2.0  32.0
# 3         40.0         2.0  33.0
# 4         40.0         2.0  34.0
# 5         38.0         2.0  35.0

# %%
QUERY = """
SELECT ConvertedComp
FROM master where Age between 45 and 60 group by Age 
"""
ck = pd.read_sql_query(QUERY,conn)
ck
# Out:
#     ConvertedComp
# 0         72522.0
# 1        118000.0
# 2        103000.0
# 3         25980.0
# 4        110509.0
# 5        115000.0
# 6         89212.0
# 7        135000.0
# 8        105000.0
# 9             NaN
# 10       150000.0
# 11            NaN
# 12        75431.0
# 13      1000000.0
# 14        75000.0
# 15       150000.0

# %%
data_removedup['MainBranch'].value_counts()
# Out:
# I am a developer by profession                                                   10618
# I am not primarily a developer, but I write code sometimes as part of my work      780
# Name: MainBranch, dtype: int64

# %%
ck.plot.line(figsize=(20, 10))
# Out:
# <AxesSubplot:>

# %%
QUERY = """
SELECT MainBranch, count(*) as count
FROM master  group by MainBranch
"""
cyk = pd.read_sql_query(QUERY,conn)
cyk
# Out:
#                                           MainBranch  count
# 0                     I am a developer by profession  10618
# 1  I am not primarily a developer, but I write co...    780

# %%
cyk.plot.barh(x='MainBranch', y='count', figsize=(20, 10))
# Out:
# <AxesSubplot:ylabel='MainBranch'>

# %%
tk.plot.bar(x='Age', stacked=True, title='The number of Hrs', figsize=(20, 10))
# Out:
# <AxesSubplot:title={'center':'The number of Hrs'}, xlabel='Age'>

# %%
df2 = dff[:5].copy()
df2
# Out:
#                                                     Respondent   CompTotal  \
# DatabaseDesireNextYear
# Cassandra                                               554953  16404379.1
# Cassandra;Couchbase                                      93703   2376095.4
# Cassandra;Couchbase;DynamoDB                             24707    757047.7
# Cassandra;Couchbase;DynamoDB;Elasticsearch               10759    130000.0
# Cassandra;Couchbase;DynamoDB;Elasticsearch;Fire...       20949    900000.0
#
#                                                     ConvertedComp  \
# DatabaseDesireNextYear
# Cassandra                                               3108258.0
# Cassandra;Couchbase                                      599742.0
# Cassandra;Couchbase;DynamoDB                             115464.0
# Cassandra;Couchbase;DynamoDB;Elasticsearch               115464.0
# Cassandra;Couchbase;DynamoDB;Elasticsearch;Fire...        29019.0
#
#                                                     WorkWeekHrs  CodeRevHrs  \
# DatabaseDesireNextYear
# Cassandra                                                1864.0  209.986427
# Cassandra;Couchbase                                       313.0   35.781071
# Cassandra;Couchbase;DynamoDB                               50.0   10.000000
# Cassandra;Couchbase;DynamoDB;Elasticsearch                 40.0    1.000000
# Cassandra;Couchbase;DynamoDB;Elasticsearch;Fire...         45.0   10.000000
#
#                                                        Age  \
# DatabaseDesireNextYear
# Cassandra                                           1330.0
# Cassandra;Couchbase                                  195.0
# Cassandra;Couchbase;DynamoDB                          23.0
# Cassandra;Couchbase;DynamoDB;Elasticsearch            30.0
# Cassandra;Couchbase;DynamoDB;Elasticsearch;Fire...    51.0
#
#                                                     NormalizedAnnualCompensation
# DatabaseDesireNextYear
# Cassandra                                                             51579499.8
# Cassandra;Couchbase                                                   25895144.8
# Cassandra;Couchbase;DynamoDB                                           9084572.4
# Cassandra;Couchbase;DynamoDB;Elasticsearch                              130000.0
# Cassandra;Couchbase;DynamoDB;Elasticsearch;Fire...                      900000.0

# %%
conn.close()
